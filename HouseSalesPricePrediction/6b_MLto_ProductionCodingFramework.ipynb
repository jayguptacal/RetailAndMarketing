# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Machine-Learning-Modeling-Summary-For-Production-Coding-Purpose" data-toc-modified-id="Machine-Learning-Modeling-Summary-For-Production-Coding-Purpose-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Machine Learning Modeling Summary For Production Coding Purpose<a id="6_Machine_Learning_Modeling_Summary"></a></a></span><ul class="toc-item"><li><span><a href="#Executive-Summary" data-toc-modified-id="Executive-Summary-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Executive Summary<a id="6.1_Executive_Summary"></a></a></span></li><li><span><a href="#Importing-Packages" data-toc-modified-id="Importing-Packages-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Importing Packages<a id="6.2_Imports"></a></a></span></li><li><span><a href="#Loading-the-Dataset" data-toc-modified-id="Loading-the-Dataset-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Loading the Dataset<a id="6.3_Loading_Dataset"></a></a></span></li><li><span><a href="#Separating-Dataset-into-Training-and-Testing" data-toc-modified-id="Separating-Dataset-into-Training-and-Testing-6.4"><span class="toc-item-num">6.4&nbsp;&nbsp;</span>Separating Dataset into Training and Testing<a id="6.4_Separating_Dataset"></a></a></span></li><li><span><a href="#Selecting-Features-for-Training" data-toc-modified-id="Selecting-Features-for-Training-6.5"><span class="toc-item-num">6.5&nbsp;&nbsp;</span>Selecting Features for Training<a id="6.5_Selecting_Features"></a></a></span></li><li><span><a href="#Feature-Engineering-for-Missing-Values" data-toc-modified-id="Feature-Engineering-for-Missing-Values-6.6"><span class="toc-item-num">6.6&nbsp;&nbsp;</span>Feature Engineering for Missing Values<a id="6.6_Feature_Engineering"></a></a></span><ul class="toc-item"><li><span><a href="#Missing-Values-Imputation-for-Categorical-Variables" data-toc-modified-id="Missing-Values-Imputation-for-Categorical-Variables-6.6.1"><span class="toc-item-num">6.6.1&nbsp;&nbsp;</span>Missing Values Imputation for Categorical Variables<a id="6.6.1_Categorical_Variables_Imputation"></a></a></span></li><li><span><a href="#Missing-Values-Imputation-for-Numerical-Variables" data-toc-modified-id="Missing-Values-Imputation-for-Numerical-Variables-6.6.2"><span class="toc-item-num">6.6.2&nbsp;&nbsp;</span>Missing Values Imputation for Numerical Variables<a id="6.6.2_Numerical_Variables_Imputation"></a></a></span></li></ul></li><li><span><a href="#Feature-Engineering-for-Temporal-Variables" data-toc-modified-id="Feature-Engineering-for-Temporal-Variables-6.7"><span class="toc-item-num">6.7&nbsp;&nbsp;</span>Feature Engineering for Temporal Variables<a id="6.7_Feature_Engineering"></a></a></span></li><li><span><a href="#Log-Transformation-of-Numerical-Variables" data-toc-modified-id="Log-Transformation-of-Numerical-Variables-6.8"><span class="toc-item-num">6.8&nbsp;&nbsp;</span>Log Transformation of Numerical Variables<a id="6.8_LogTransformation_NumericalVariables"></a></a></span></li><li><span><a href="#Feature-Engineering-of-Categorical-Variables" data-toc-modified-id="Feature-Engineering-of-Categorical-Variables-6.9"><span class="toc-item-num">6.9&nbsp;&nbsp;</span>Feature Engineering of Categorical Variables<a id="6.9_FeatureEngineering_CategoricalVariables"></a></a></span><ul class="toc-item"><li><span><a href="#Identification-of-Frequent-&amp;-Rare-Labels" data-toc-modified-id="Identification-of-Frequent-&amp;-Rare-Labels-6.9.1"><span class="toc-item-num">6.9.1&nbsp;&nbsp;</span>Identification of Frequent &amp; Rare Labels<a id="6.9.1_Frequent_Rare_Variables"></a></a></span></li><li><span><a href="#Encoding-of-Categorical-Variables" data-toc-modified-id="Encoding-of-Categorical-Variables-6.9.2"><span class="toc-item-num">6.9.2&nbsp;&nbsp;</span>Encoding of Categorical Variables<a id="6.9.2_Encoding_Categorical_Variables"></a></a></span></li><li><span><a href="#Features-Scaling" data-toc-modified-id="Features-Scaling-6.9.3"><span class="toc-item-num">6.9.3&nbsp;&nbsp;</span>Features Scaling<a id="6.9.3_Features_Scaling"></a></a></span></li></ul></li><li><span><a href="#Training-of-Lasso-Linear-Regression-Model" data-toc-modified-id="Training-of-Lasso-Linear-Regression-Model-6.10"><span class="toc-item-num">6.10&nbsp;&nbsp;</span>Training of Lasso Linear Regression Model<a id="6.10_Training_LassoModel"></a></a></span></li><li><span><a href="#Scoring-or-Evaluating-Lasso-Linear-Regression-Model" data-toc-modified-id="Scoring-or-Evaluating-Lasso-Linear-Regression-Model-6.11"><span class="toc-item-num">6.11&nbsp;&nbsp;</span>Scoring or Evaluating Lasso Linear Regression Model<a id="6.11_Scoring_LassoModel"></a></a></span></li><li><span><a href="#Next-Steps" data-toc-modified-id="Next-Steps-6.12"><span class="toc-item-num">6.12&nbsp;&nbsp;</span>Next Steps<a id="6.12_Next_Steps"></a></a></span></li><li><span><a href="#Overview-of-Execution-Steps-for-the-Next-Phase" data-toc-modified-id="Overview-of-Execution-Steps-for-the-Next-Phase-6.13"><span class="toc-item-num">6.13&nbsp;&nbsp;</span>Overview of Execution Steps for the Next Phase<a id="6.13_Execution_Steps"></a></a></span></li><li><span><a href="#Quick-Access-to-various-Jupyter-Notebooks" data-toc-modified-id="Quick-Access-to-various-Jupyter-Notebooks-6.14"><span class="toc-item-num">6.14&nbsp;&nbsp;</span>Quick Access to various Jupyter Notebooks<a id="6.14_Jupyter_Notebooks"></a></a></span></li></ul></li></ul></div>

# %% [markdown]
# # Machine Learning Modeling Summary For Production Coding Purpose<a id='6_Machine_Learning_Modeling_Summary'></a>

# %% [markdown]
# ## Executive Summary<a id='6.1_Executive_Summary'></a>

# %% [markdown]
# Focus is mainly on putting up with the needs for writing the production code which includes our final steps including the hard coding of variables required as well as hard coding of any type of imputation or values.
#
# For easy reference, I am sharing the Deployment steps for the development of the machine learning model as shown below:

# %% [markdown]
# ![DeploymentSteps2.jpg](attachment:DeploymentSteps2.jpg)

# %% [markdown]
# Since the main focus will be on using the current machine learning model and breaking it down to production code methodology using the **procedural programming** framework which is simplistic in nature as it mimics the machine learning model.
#
# While I am focused on the production coding, I am also focused on ensuring that I am not breaking the current machine learning code by mistake so I am running the code to keep checking that everything is working properly.

# %% [markdown]
# ## Importing Packages<a id='6.2_Imports'></a>

# %%
# Packages required for the preprocessing script - Part of PREPROCESSING_FUNCTIONS.PY

import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import Lasso
import joblib

# Packages required for the train script - Part of TRAIN.PY(# to be removed before putting in the coding file)

#import numpy as np
#import preprocessing_functions as pf
#import config
import warnings
warnings.simplefilter(action='ignore')

# Packages required for the score script - Part of SCORE.PY (# to be removed before putting in the coding file)

#import preprocessing_functions as pf
#import config
from sklearn.metrics import mean_squared_error, r2_score
from math import sqrt

# %% [markdown]
# ## Loading the Dataset<a id='6.3_Loading_Dataset'></a>

# %%
# Created a separate folder named 'production' where the 'houseprice.csv' is saved for production purpose
data = pd.read_csv('../HousePricesPrediction/production/houseprice.csv')
data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %% [markdown]
# **CODE FOR CONFIG.PY:**
#
# PATH_TO_DATASET = "houseprice.csv"
# data = pf.load_data(config.PATH_TO_DATASET)
#
# **CODE FOR PREPROCESSING_FUNCTIONS.PY defined functions:**
#
# def load_data(df_path):
#     return pd.read_csv(df_path)

# %% [markdown]
# ## Separating Dataset into Training and Testing<a id='6.4_Separating_Dataset'></a>

# %%
X_train, X_test, y_train, y_test = train_test_split(data, data['SalePrice'], test_size=0.1,random_state=0)
X_train.shape, X_test.shape
# Out:
# ((1314, 81), (146, 81))

# %% [markdown]
# **CODE FOR TRAIN.PY:**
# X_train, X_test, y_train, y_test = pf.divide_train_test(data, config.TARGET)

# %% [markdown]
# ## Selecting Features for Training<a id='6.5_Selecting_Features'></a>

# %%
# loading selected features file here
features = pd.read_csv('../HousePricesPrediction/production/selected_features.csv')

# Now adding the extra feature, LotFrontage
features = features['0'].to_list() + ['LotFrontage']

print('Number of features for production coding: ', len(features))
# Out:
# Number of features for production coding:  23

# %%
features
# Out:
# ['MSSubClass',
#  'MSZoning',
#  'Neighborhood',
#  'OverallQual',
#  'YearRemodAdd',
#  'RoofStyle',
#  'MasVnrType',
#  'ExterQual',
#  'BsmtQual',
#  'BsmtExposure',
#  'HeatingQC',
#  'CentralAir',
#  '1stFlrSF',
#  'GrLivArea',
#  'BsmtFullBath',
#  'KitchenQual',
#  'Fireplaces',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageCars',
#  'PavedDrive',
#  'LotFrontage']

# %% [markdown]
# **CODE FOR CONFIG.PY:**
#
# FEATURES = ['MSSubClass', 'MSZoning', 'Neighborhood', 'OverallQual', 'OverallCond', 'YearRemodAdd', 'RoofStyle', 'MasVnrType','BsmtQual', 'BsmtExposure', 'HeatingQC', 'CentralAir','1stFlrSF', 'GrLivArea', 'BsmtFullBath', 'KitchenQual','Fireplaces', 'FireplaceQu', 'GarageType', 'GarageFinish','GarageCars', 'PavedDrive', 'LotFrontage']

# %% [markdown]
# ## Feature Engineering for Missing Values<a id='6.6_Feature_Engineering'></a>

# %% [markdown]
# ### Missing Values Imputation for Categorical Variables<a id='6.6.1_Categorical_Variables_Imputation'></a>

# %%
# Identifying missing values for the categorical variables
vars_with_na = [var for var in features if X_train[var].isnull().sum() > 0 and X_train[var].dtypes == 'O']
vars_with_na
# Out:
# ['MasVnrType',
#  'BsmtQual',
#  'BsmtExposure',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish']

# %% [markdown]
# **CODE FOR CONFIG.PY:**
# CATEGORICAL_TO_IMPUTE = ['MasVnrType', 'BsmtQual', 'BsmtExposure', 'FireplaceQu', 'GarageType', 'GarageFinish']

# %%
# Imputing above categorical variables with 'Missing' string
X_train[vars_with_na] = X_train[vars_with_na].fillna('Missing')
X_test[vars_with_na] = X_test[vars_with_na].fillna('Missing')

# Checking that there is no missing information in the engineered categorical variables
X_train[vars_with_na].isnull().sum()
# Out:
# MasVnrType      0
# BsmtQual        0
# BsmtExposure    0
# FireplaceQu     0
# GarageType      0
# GarageFinish    0
# dtype: int64

# %% [markdown]
# **CODE FOR PREPROCESSING_FUNCTIONS.PY defined functions:**
# def impute_na(df, var, replacement='Missing'):
#     return df[var].fillna(replacement)
#
# **CODE FOR TRAIN.PY:**
# for var in config.CATEGORICAL_TO_IMPUTE:
#     X_train[var] = pf.impute_na(X_train, var, replacement='Missing')

# %% [markdown]
# ### Missing Values Imputation for Numerical Variables<a id='6.6.2_Numerical_Variables_Imputation'></a>

# %%
# Identifying missing values for the numerical variables
vars_with_na = [var for var in features if X_train[var].isnull().sum() > 0 and X_train[var].dtypes != 'O']
vars_with_na
# Out:
# ['LotFrontage']

# %%
# Finding the mode value for the 'LotFrontage' variable and then imputing it.
var = 'LotFrontage'

# First calculating the mode
mode_val = X_train[var].mode()[0]
print('Mode Value for LotFrontage: {}'.format(mode_val))

# Imputing missing values by the above mode value for both training and testing dataset
X_train[var] = X_train[var].fillna(mode_val)
X_test[var] = X_test[var].fillna(mode_val)
# Out:
# Mode Value for LotFrontage: 60.0

# %% [markdown]
# **CODE FOR CONFIG.PY:**
# NUMERICAL_TO_IMPUTE = 'LotFrontage'
#
# **CODE FOR CONFIG.PY for the LotFrontage Value to be hardcoded:**
# LOTFRONTAGE_MODE = 60
#
# **CODE FOR TRAIN.PY:**
# X_train[config.NUMERICAL_TO_IMPUTE] = pf.impute_na(X_train,
#        config.NUMERICAL_TO_IMPUTE,
#        replacement=config.LOTFRONTAGE_MODE)

# %% [markdown]
# ## Feature Engineering for Temporal Variables<a id='6.7_Feature_Engineering'></a>

# %%
# During the EDA phase, 'YearRemodAdd' was selected for the final modeling as temporal variable
# Creating engineered variable with defined function
def elapsed_years(df, var):
    # capture difference between year variable and year in which the house was sold
    df[var] = df['YrSold'] - df[var]
    return df

# Using the above defined function for both training and testing dataset
X_train = elapsed_years(X_train, 'YearRemodAdd')
X_test = elapsed_years(X_test, 'YearRemodAdd')

# %% [markdown]
# **CODE FOR CONFIG.PY:**
# YEAR_VARIABLE = 'YearRemodAdd'
#
# **CODE FOR PREPROCESSING_FUNCTIONS.PY defined functions:**
# def elapsed_years(df, var, ref_var='YrSold'):
#     df[var] = df[ref_var] - df[var]
#     return df
#
# **CODE FOR TRAIN.PY:**
# X_train[config.YEAR_VARIABLE] = pf.elapsed_years(X_train,config.YEAR_VARIABLE, ref_var='YrSold')

# %% [markdown]
# ## Log Transformation of Numerical Variables<a id='6.8_LogTransformation_NumericalVariables'></a>

# %%
# Log transformation of numerical variables including the target variable 'SalePrice'

for var in ['LotFrontage', '1stFlrSF', 'GrLivArea', 'SalePrice']:
    X_train[var] = np.log(X_train[var])
    X_test[var] = np.log(X_test[var])

# %% [markdown]
# **CODE FOR CONFIG.PY:**
# NUMERICAL_LOG = ['LotFrontage', '1stFlrSF', 'GrLivArea', 'SalePrice']
#
# **CODE FOR PREPROCESSING_FUNCTIONS.PY defined functions:**
# def log_transform(df, var):
#     return np.log(df[var])
#
# **CODE FOR TRAIN.PY:**
# for var in config.NUMERICAL_LOG:
#     X_train[var] = pf.log_transform(X_train, var)

# %% [markdown]
# ## Feature Engineering of Categorical Variables<a id='6.9_FeatureEngineering_CategoricalVariables'></a>

# %% [markdown]
# ### Identification of Frequent & Rare Labels<a id='6.9.1_Frequent_Rare_Variables'></a>

# %%
# Identifying the list of categorical variables first
cat_vars = [var for var in features if X_train[var].dtype == 'O']
cat_vars
# Out:
# ['MSZoning',
#  'Neighborhood',
#  'RoofStyle',
#  'MasVnrType',
#  'ExterQual',
#  'BsmtQual',
#  'BsmtExposure',
#  'HeatingQC',
#  'CentralAir',
#  'KitchenQual',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'PavedDrive']

# %%
# Defined a function to filter the rare labels
def find_frequent_labels(df, var, rare_perc):
    # Find the labels that are shared by more than a certain % of the houses in the dataset
    df = df.copy()
    tmp = df.groupby(var)['SalePrice'].count() / len(df)
    return tmp[tmp > rare_perc].index

# Finding the frequent categories for the dataset
for var in cat_vars:
    frequent_ls = find_frequent_labels(X_train, var, 0.01)
    print("Variable name is: ", var)
    print("Frequent labels are:", frequent_ls)
    print()
    
    # Replace rare categories by the string "Rare"
    X_train[var] = np.where(X_train[var].isin(frequent_ls), X_train[var], 'Rare')
    
    X_test[var] = np.where(X_test[var].isin(frequent_ls), X_test[var], 'Rare')
# Out:
# Variable name is:  MSZoning
# Frequent labels are: Index(['FV', 'RH', 'RL', 'RM'], dtype='object', name='MSZoning')
#
# Variable name is:  Neighborhood
# Frequent labels are: Index(['Blmngtn', 'BrDale', 'BrkSide', 'ClearCr', 'CollgCr', 'Crawfor',
#        'Edwards', 'Gilbert', 'IDOTRR', 'MeadowV', 'Mitchel', 'NAmes', 'NWAmes',
#        'NoRidge', 'NridgHt', 'OldTown', 'SWISU', 'Sawyer', 'SawyerW',
#        'Somerst', 'StoneBr', 'Timber'],
#       dtype='object', name='Neighborhood')
#
# Variable name is:  RoofStyle
# Frequent labels are: Index(['Gable', 'Hip'], dtype='object', name='RoofStyle')
#
# Variable name is:  MasVnrType
# Frequent labels are: Index(['BrkFace', 'None', 'Stone'], dtype='object', name='MasVnrType')
#
# Variable name is:  ExterQual
# Frequent labels are: Index(['Ex', 'Gd', 'TA'], dtype='object', name='ExterQual')
#
# Variable name is:  BsmtQual
# Frequent labels are: Index(['Ex', 'Fa', 'Gd', 'Missing', 'TA'], dtype='object', name='BsmtQual')
#
# ...

# %% [markdown]
# **CODE FOR CONFIG.PY:**
# FREQUENT_LABELS = {'MSZoning': ['FV', 'RH', 'RL', 'RM'], 'Neighborhood': ['Blmngtn', 'BrDale', 'BrkSide', 'ClearCr', 'CollgCr','Crawfor', 'Edwards', 'Gilbert', 'IDOTRR', 'MeadowV','Mitchel', 'NAmes', 'NWAmes', 'NoRidge', 'NridgHt','OldTown', 'SWISU', 'Sawyer', 'SawyerW', 'Somerst','StoneBr', 'Timber'],'RoofStyle': ['Gable', 'Hip'],'MasVnrType': ['BrkFace', 'None', 'Stone'],'BsmtQual': ['Ex', 'Fa', 'Gd', 'Missing', 'TA'],'BsmtExposure': ['Av', 'Gd', 'Missing', 'Mn', 'No'],'HeatingQC': ['Ex', 'Fa', 'Gd', 'TA'],'CentralAir': ['N', 'Y'],'KitchenQual': ['Ex', 'Fa', 'Gd', 'TA'],'FireplaceQu': ['Ex', 'Fa', 'Gd', 'Missing', 'Po', 'TA'],'GarageType': ['Attchd', 'Basment', 'BuiltIn', 'Detchd', 'Missing'],'GarageFinish': ['Fin', 'Missing', 'RFn', 'Unf'],'PavedDrive': ['N', 'P', 'Y']}
#
# **CODE FOR PREPROCESSING_FUNCTIONS.PY defined functions:**
# def remove_rare_labels(df, var, frequent_labels):
#     return np.where(df[var].isin(frequent_labels), df[var], 'Rare')
#
# **CODE FOR TRAIN.PY:**
# for var in config.CATEGORICAL_ENCODE:
#     X_train[var] = pf.remove_rare_labels(X_train, var, config.FREQUENT_LABELS[var])

# %% [markdown]
# ### Encoding of Categorical Variables<a id='6.9.2_Encoding_Categorical_Variables'></a>

# %%
# Defining a function to assign discreet values to categorical variables from the lowest to highest
# in comparison with target variable 

def replace_categories(train, test, var, target):
    ordered_labels = train.groupby([var])[target].mean().sort_values().index
    # create a dictionary of ordered categories to integer values
    ordinal_label = {k: i for i, k in enumerate(ordered_labels, 0)}

    # use the dictionary to replace the categorical strings by integers
    train[var] = train[var].map(ordinal_label)
    test[var] = test[var].map(ordinal_label)
    
    print(var)
    print(ordinal_label)
    print()

# %%
# Replacing categories with discreet values
for var in cat_vars:
    replace_categories(X_train, X_test, var, 'SalePrice')
# Out:
# MSZoning
# {'Rare': 0, 'RM': 1, 'RH': 2, 'RL': 3, 'FV': 4}
#
# Neighborhood
# {'IDOTRR': 0, 'MeadowV': 1, 'BrDale': 2, 'Edwards': 3, 'BrkSide': 4, 'OldTown': 5, 'Sawyer': 6, 'SWISU': 7, 'NAmes': 8, 'Mitchel': 9, 'SawyerW': 10, 'Rare': 11, 'NWAmes': 12, 'Gilbert': 13, 'Blmngtn': 14, 'CollgCr': 15, 'Crawfor': 16, 'ClearCr': 17, 'Somerst': 18, 'Timber': 19, 'StoneBr': 20, 'NridgHt': 21, 'NoRidge': 22}
#
# RoofStyle
# {'Gable': 0, 'Rare': 1, 'Hip': 2}
#
# MasVnrType
# {'None': 0, 'Rare': 1, 'BrkFace': 2, 'Stone': 3}
#
# ExterQual
# {'Rare': 0, 'TA': 1, 'Gd': 2, 'Ex': 3}
#
# BsmtQual
# {'Missing': 0, 'Fa': 1, 'TA': 2, 'Gd': 3, 'Ex': 4}
#
# BsmtExposure
# {'Missing': 0, 'No': 1, 'Mn': 2, 'Av': 3, 'Gd': 4}
#
# HeatingQC
# {'Rare': 0, 'Fa': 1, 'TA': 2, 'Gd': 3, 'Ex': 4}
#
# CentralAir
# {'N': 0, 'Y': 1}
#
# KitchenQual
# {'Fa': 0, 'TA': 1, 'Gd': 2, 'Ex': 3}
#
# FireplaceQu
# {'Po': 0, 'Missing': 1, 'Fa': 2, 'TA': 3, 'Gd': 4, 'Ex': 5}
#
# GarageType
# ...

# %%
X_train.head()
# Out:
#         Id  MSSubClass  MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 930    931          20         3     4.290459     8925   Pave   NaN      IR1
# 656    657          20         3     4.276666    10007   Pave   NaN      IR1
# 45      46         120         3     4.110874     7658   Pave   NaN      Reg
# 1348  1349          20         3     4.094345    16196   Pave   NaN      IR3
# 55      56          20         3     4.605170    10175   Pave   NaN      IR1
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 930          HLS    AllPub  ...        0    NaN    NaN         NaN       0
# 656          Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 45           Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1348         Low    AllPub  ...        0    NaN    NaN         NaN       0
# 55           Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
# ...

# %%
X_train.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1314 entries, 930 to 684
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1314 non-null   int64
#  1   MSSubClass     1314 non-null   int64
#  2   MSZoning       1314 non-null   int64
#  3   LotFrontage    1314 non-null   float64
#  4   LotArea        1314 non-null   int64
#  5   Street         1314 non-null   object
#  6   Alley          81 non-null     object
#  7   LotShape       1314 non-null   object
#  8   LandContour    1314 non-null   object
#  9   Utilities      1314 non-null   object
#  10  LotConfig      1314 non-null   object
#  11  LandSlope      1314 non-null   object
#  12  Neighborhood   1314 non-null   int64
#  13  Condition1     1314 non-null   object
#  14  Condition2     1314 non-null   object
#  15  BldgType       1314 non-null   object
#  16  HouseStyle     1314 non-null   object
# ...

# %% [markdown]
# **CODE FOR CONFIG.PY:**
# CATEGORICAL_ENCODE = ['MSZoning', 'Neighborhood', 'RoofStyle',
#                           'MasVnrType', 'BsmtQual', 'BsmtExposure',
#                           'HeatingQC', 'CentralAir', 'KitchenQual',
#                           'FireplaceQu', 'GarageType', 'GarageFinish',
#                           'PavedDrive']
#
# ENCODING_MAPPINGS = {'MSZoning': {'Rare': 0, 'RM': 1, 'RH': 2, 'RL': 3, 'FV': 4},
#                      'Neighborhood': {'IDOTRR': 0, 'MeadowV': 1, 'BrDale': 2, 'Edwards': 3,
#                                       'BrkSide': 4, 'OldTown': 5, 'Sawyer': 6, 'SWISU': 7, 'NAmes': 8,
#                                       'Mitchel': 9, 'SawyerW': 10, 'Rare': 11, 'NWAmes': 12, 'Gilbert': 13,
#                                       'Blmngtn': 14, 'CollgCr': 15, 'Crawfor': 16, 'ClearCr': 17, 'Somerst': 18,
#                                       'Timber': 19, 'StoneBr': 20, 'NridgHt': 21, 'NoRidge': 22},
#                      'RoofStyle': {'Gable': 0, 'Rare': 1, 'Hip': 2},
#                      'MasVnrType': {'None': 0, 'Rare': 1, 'BrkFace': 2, 'Stone': 3},
#                      'BsmtQual': {'Missing': 0, 'Fa': 1, 'TA': 2, 'Gd': 3, 'Ex': 4},
#                      'BsmtExposure': {'Missing': 0, 'No': 1, 'Mn': 2, 'Av': 3, 'Gd': 4},
#                      'HeatingQC': {'Rare': 0, 'Fa': 1, 'TA': 2, 'Gd': 3, 'Ex': 4},
#                      'CentralAir': {'N': 0, 'Y': 1},
#                      'KitchenQual': {'Fa': 0, 'TA': 1, 'Gd': 2, 'Ex': 3},
#                      'FireplaceQu': {'Po': 0, 'Missing': 1, 'Fa': 2, 'TA': 3, 'Gd': 4, 'Ex': 5},
#                      'GarageType': {'Missing': 0, 'Rare': 1, 'Detchd': 2, 'Basment': 3,'Attchd': 4,'BuiltIn': 5},
#                      'GarageFinish': {'Missing': 0, 'Unf': 1, 'RFn': 2, 'Fin': 3},
#                      'PavedDrive': {'N': 0, 'P': 1, 'Y': 2}}
#
# **CODE FOR PREPROCESSING_FUNCTIONS.PY defined functions:**
# def encode_categorical(df, var, mappings):
#     # replaces strings by numbers using mappings dictionary
#     return df[var].map(mappings)
#
# **CODE FOR TRAIN.PY:**
# for var in config.CATEGORICAL_ENCODE:
#     X_train[var] = pf.encode_categorical(X_train, var,
#            config.ENCODING_MAPPINGS[var])

# %% [markdown]
# ### Features Scaling<a id='6.9.3_Features_Scaling'></a>

# %%
# Using MinMaxScaler() and removing the y_train and y_test prior scaling
y_train = X_train['SalePrice']
y_test = X_test['SalePrice']

scaler = MinMaxScaler()
# training scaler
scaler.fit(X_train[features])

# transforming the train and test set
X_train = scaler.transform(X_train[features])
X_test = scaler.transform(X_test[features])

# %% [markdown]
# **CODE FOR CONFIG.PY:**
# OUTPUT_SCALER_PATH = 'scaler.pkl'
#
# **CODE FOR PREPROCESSING_FUNCTIONS.PY defined functions:**
# def train_scaler(df, output_path):
#     scaler = MinMaxScaler()
#     scaler.fit(df)
#     joblib.dump(scaler, output_path)
#     return scaler
#
# **CODE FOR PREPROCESSING_FUNCTIONS.PY defined functions:**
# def scale_features(df, scaler):
#     scaler = joblib.load(scaler)
#     return scaler.transform(df)
#
# **CODE FOR TRAIN.PY:**
# scaler = pf.train_scaler(X_train[config.FEATURES], config.OUTPUT_SCALER_PATH)
#
# **CODE FOR TRAIN.PY:**
# X_train = scaler.transform(X_train[config.FEATURES])

# %% [markdown]
# ## Training of Lasso Linear Regression Model<a id='6.10_Training_LassoModel'></a>

# %%
# Training the Lasso model
lin_model = Lasso(alpha=0.005, random_state=0)

# training the model
lin_model.fit(X_train, y_train)

# Persist the model for future use
joblib.dump(lin_model, '../HousePricesPrediction/production/lasso_regression.pkl')
# Out:
# ['../HousePricesPrediction/production/lasso_regression.pkl']

# %% [markdown]
# **CODE FOR CONFIG.PY:**
# OUTPUT_MODEL_PATH = 'lasso_regression.pkl'
#
# **CODE FOR PREPROCESSING_FUNCTIONS.PY defined functions:**
# def train_model(df, target, output_path):
#     # initialise the model
#     lin_model = Lasso(alpha=0.005, random_state=0)
#     # train the model
#     lin_model.fit(df, target)
#     # save the model
#     joblib.dump(lin_model, output_path)
#     return None
#
# **CODE FOR TRAIN.PY:**
# pf.train_model(X_train,np.log(y_train),config.OUTPUT_MODEL_PATH)
# print('Finished training')

# %% [markdown]
# ## Scoring or Evaluating Lasso Linear Regression Model<a id='6.11_Scoring_LassoModel'></a>

# %%
# Since I did the log transformation of the whole data, I need to get the original house price values back while
# using the prediction of house prices

# Running the model for the training set
pred = lin_model.predict(X_train)

print('train mse: {}'.format(int(mean_squared_error(np.exp(y_train), np.exp(pred)))))
print('train rmse: {}'.format(int(sqrt(mean_squared_error(np.exp(y_train), np.exp(pred))))))
print('train r2: {}'.format(r2_score(np.exp(y_train), np.exp(pred))))
print()

# Running the model for the testing set
pred = lin_model.predict(X_test)

# determine mse and rmse
print('test mse: {}'.format(int(mean_squared_error(np.exp(y_test), np.exp(pred)))))
print('test rmse: {}'.format(int(sqrt(mean_squared_error(np.exp(y_test), np.exp(pred))))))
print('test r2: {}'.format(r2_score(np.exp(y_test), np.exp(pred))))
print()

# Printing the true house prices and not the log transformed value
print('Average house price: ', int(np.exp(y_train).median()))
# Out:
# train mse: 1088196970
# train rmse: 32987
# train r2: 0.8257164844366803
#
# test mse: 1405209371
# test rmse: 37486
# test r2: 0.7955201108785517
#
# Average house price:  163000

# %% [markdown]
# **CODE FOR PREPROCESSING_FUNCTIONS.PY defined functions:**
# def predict(df, model):
#     model = joblib.load(model)
#     return model.predict(df)
#
# **CODE FOR SCORE.PY: Putting as the pipeline to predict the prices**
# def predict(data):
#
#     # impute Missing Values
#     for var in config.CATEGORICAL_TO_IMPUTE:
#         data[var] = pf.impute_na(data, var, replacement='Missing')
#
#     data[config.NUMERICAL_TO_IMPUTE] = pf.impute_na(data,
#            config.NUMERICAL_TO_IMPUTE,
#            replacement=config.LOTFRONTAGE_MODE)
#
#     # Capture elapsed time
#     data[config.YEAR_VARIABLE] = pf.elapsed_years(data,
#            config.YEAR_VARIABLE, ref_var='YrSold')
#
#     # log transform numerical variables
#     for var in config.NUMERICAL_LOG:
#        data[var] = pf.log_transform(data, var)
#
#     # Group rare labels
#     for var in config.CATEGORICAL_ENCODE:
#         data[var] = pf.remove_rare_labels(data, var, config.FREQUENT_LABELS[var])
#
#     # encode variables
#     for var in config.CATEGORICAL_ENCODE:
#         data[var] = pf.encode_categorical(data, var,config.ENCODING_MAPPINGS[var])
#
#     # scale variables
#     data = pf.scale_features(data[config.FEATURES],config.OUTPUT_SCALER_PATH)
#
#     # make predictions
#     predictions = pf.predict(data, config.OUTPUT_MODEL_PATH)
#
#     return predictions

# %% [markdown]
# ## Next Steps<a id='6.12_Next_Steps'></a>

# %% [markdown]
# Since the main focus of the problem solving is to quickly deploy the model keeping the simplicity, minimum time for the development and this model is for proof of concept only and not for the production environment, I am following the below steps and keeping the production coding a very simple exercise:
#
# - I have created next notebook with code being shown for the Streamlit app using simpler code rather than the production code
# - After completing the Streamlit app, I plan to connect to Heroku via GitHub repository
# - this approach will save a lot of time focusing on the proof of concept
#
# Also this is a good reminder to keep focused on the minimum viable product and focus on the improvements later.
#
# ![ImageMVP.jpg](attachment:ImageMVP.jpg)

# %% [markdown]
# ## Overview of Execution Steps for the Next Phase<a id='6.13_Execution_Steps'></a>

# %% [markdown]
# ![infographml6.jpg](attachment:infographml6.jpg)

# %% [markdown]
# ## Quick Access to various Jupyter Notebooks<a id='6.14_Jupyter_Notebooks'></a>

# %% [markdown]
# Based on the DSM methodology, a dedicated jupyter notebook was created to focus on one aspect at a time and you can refer these notebooks from the below links:
#
#    1. For **Problem Identification Notebook** - [click here](https://github.com/jayguptacal/RetailAndMarketing/blob/main/HouseSalesPricePrediction/1_Problem_Identification_House_Prices.ipynb)
#    2. For **Data Wrangling Notebook**, [click here](https://github.com/jayguptacal/RetailAndMarketing/blob/main/HouseSalesPricePrediction/2_Data_Wrangling_House_Prices.ipynb)
#    3. For **Exploratory Data Analysis Notebook**, [click here](https://github.com/jayguptacal/RetailAndMarketing/blob/main/HouseSalesPricePrediction/3_EDA_House_Prices.ipynb)
#    4. For **Pre-Processing and Training Data Development Notebook**, [click here](https://github.com/jayguptacal/RetailAndMarketing/blob/main/HouseSalesPricePrediction/4_Preprocessing_TrainingData_HousePrices.ipynb)
#    5. For **Machine Learning Notebook**, [click here](https://github.com/jayguptacal/RetailAndMarketing/blob/main/HouseSalesPricePrediction/5_Machine_Learning_House_Prices.ipynb)
#    6. For **Full ML Model for Production Purpose**, [click here](https://github.com/jayguptacal/RetailAndMarketing/blob/main/HouseSalesPricePrediction/6a_FullMLPipeline_ProductionPurpose.ipynb)
