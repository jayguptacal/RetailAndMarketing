# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Problem-Identification:-Development-of-Real-Estate-House-Prediction-Demo-App-from-the-Proof-of-Concept-(PoC)-to-Deployment-Stage" data-toc-modified-id="Problem-Identification:-Development-of-Real-Estate-House-Prediction-Demo-App-from-the-Proof-of-Concept-(PoC)-to-Deployment-Stage-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Problem Identification: Development of Real Estate House Prediction Demo App from the Proof of Concept (PoC) to Deployment Stage<a id="1_Problem_Identification"></a></a></span><ul class="toc-item"><li><span><a href="#Introduction" data-toc-modified-id="Introduction-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Introduction<a id="1.1_Introduction"></a></a></span></li><li><span><a href="#Problem-Identification" data-toc-modified-id="Problem-Identification-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Problem Identification<a id="1.2_Problem_Identification"></a></a></span></li><li><span><a href="#Description-of-Data-Features" data-toc-modified-id="Description-of-Data-Features-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Description of Data Features<a id="1.4_Description_Data_Features"></a></a></span></li><li><span><a href="#Project-Planning-Steps" data-toc-modified-id="Project-Planning-Steps-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Project Planning Steps<a id="1.4_Project_Plan"></a></a></span></li><li><span><a href="#Execution-Plan" data-toc-modified-id="Execution-Plan-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Execution Plan<a id="1.5_Execution_Plan"></a></a></span><ul class="toc-item"><li><span><a href="#Architecture-Diagram" data-toc-modified-id="Architecture-Diagram-1.5.1"><span class="toc-item-num">1.5.1&nbsp;&nbsp;</span>Architecture Diagram<a id="1.4.1_Architecture_Diagram"></a></a></span></li><li><span><a href="#Machine-Learning-Pipeline" data-toc-modified-id="Machine-Learning-Pipeline-1.5.2"><span class="toc-item-num">1.5.2&nbsp;&nbsp;</span>Machine Learning Pipeline<a id="1.4.2_Machine_Learning_Pipeline"></a></a></span></li><li><span><a href="#Machine-Learning-App-Deployment" data-toc-modified-id="Machine-Learning-App-Deployment-1.5.3"><span class="toc-item-num">1.5.3&nbsp;&nbsp;</span>Machine Learning App Deployment<a id="1.4.3_Application_Deployment"></a></a></span></li><li><span><a href="#Project-Documentation" data-toc-modified-id="Project-Documentation-1.5.4"><span class="toc-item-num">1.5.4&nbsp;&nbsp;</span>Project Documentation<a id="1.4.4_Project_Documentation"></a></a></span></li></ul></li><li><span><a href="#Summary" data-toc-modified-id="Summary-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Summary<a id="1.X_Summary"></a></a></span></li><li><span><a href="#Overview-of-Execution-Steps-for-the-Next-Phase" data-toc-modified-id="Overview-of-Execution-Steps-for-the-Next-Phase-1.7"><span class="toc-item-num">1.7&nbsp;&nbsp;</span>Overview of Execution Steps for the Next Phase<a id="1.6_Execution_Steps"></a></a></span></li><li><span><a href="#Quick-Access-to-various-Jupyter-Notebooks" data-toc-modified-id="Quick-Access-to-various-Jupyter-Notebooks-1.8"><span class="toc-item-num">1.8&nbsp;&nbsp;</span>Quick Access to various Jupyter Notebooks<a id="1.8_Jupyter_Notebooks"></a></a></span></li></ul></li></ul></div>

# %% [markdown]
# # Problem Identification: Development of Real Estate House Prediction Demo App from the Proof of Concept (PoC) to Deployment Stage<a id='1_Problem_Identification'></a>

# %% [markdown]
# The data science methodology for the overall analysis for this project will be done in the Jupyter Notebooks using the following process as shown below:
#
# ![MLinfograph1.jpg](attachment:MLinfograph1.jpg)

# %% [markdown]
# This Jupyter notebook applies to the first phase of the problem identification stage only.
#
# ![problemstatement-2.png](attachment:problemstatement-2.png)

# %% [markdown]
# ## Introduction<a id='1.1_Introduction'></a>

# %% [markdown]
# During the start-up phase of any company, it's hard to hire a full team of data science professionals. Imagine if the founders want an idea to be tested quickly without incurring any expenses. This is the problem faced by many data science professionals. To simulate the similar situations for a start-up real-estate company, I am building a new machine learning model predicting the house prices. The main idea is to empower the users to check their house prices and get the full report via email which will be used to connect with the users and then use that email to start building the relationship with the users.
#
# Being a start-up, the budget is zero. Hence the main idea here is to test out the concept first and build a demo application quickly using the open-source resources and then demonstrate it to the management team to show them the power of the pilot project.
#
# Keeping this in mind, the primary focus of this project is to predict the house prices for the given dataset using machine learning models. In order build this model, I am going to use the publicly available dataset for predicting house prices. Once the model is built, then it will be deployed as an interface for the private use for the demonstration purpose only.
#
# **The focus of this project is to demonstrate a minimum viable product (MVP) to stakeholders (start-up partners) that a production-ready application can be launched with this conept.**

# %% [markdown]
# ![houses.jpg](attachment:houses.jpg)

# %% [markdown]
# The dataset is compiled by Dean De Cock from [Journal of Statistics Education](http://jse.amstat.org/v19n3/decock.pdf) for the purpose of machine learning projects. This dataset has been provided by Dean De Cock at Kaggle for the data science community to do machine learning projects and participate in their competitions.
#
# I have downloaded the dataset from [Predict House Sales Price](https://www.kaggle.com/c/house-prices-advanced-regression-techniques/data) for this project purpose.

# %% [markdown]
# ## Problem Identification<a id='1.2_Problem_Identification'></a>

# %% [markdown]
# The main goal is to predict house sales prices based on various house features for the given dataset using machine learning algorithms and identify the best machine learning algorigthm.
#
# In order to achieve the above main goal, I will also focus on the following:
#
# - Create a **machine learning pipeline** for the production purpose
# - Create code for the **deployment purpose** based on the Jupyter Notebooks
# - Create a private location for the "**house sales price prediction app**" for the demonstration purpose only
# - Keep the main focus in mind that this is a minimum viable product (MVP) scenario where I need to **focus on demonstration of a working concept** and speed rather than making it perfect for the users

# %% [markdown]
# ## Description of Data Features<a id='1.4_Description_Data_Features'></a>

# %% [markdown]
# Here is a brief introduction of various features for the given dataset:
#
#
# - **SalePrice** - the property's sale price in dollars. This is the target variable that you're trying to predict.
# - **MSSubClass**: The building class
# - **MSZoning**: The general zoning classification
# - **LotFrontage**: Linear feet of street connected to property
# - **LotArea**: Lot size in square feet
# - **Street**: Type of road access
# - **Alley**: Type of alley access
# - **LotShape**: General shape of property
# - **LandContour**: Flatness of the property
# - **Utilities**: Type of utilities available
# - **LotConfig**: Lot configuration
# - **LandSlope**: Slope of property
# - **Neighborhood**: Physical locations within Ames city limits
# - **Condition1**: Proximity to main road or railroad
# - **Condition2**: Proximity to main road or railroad (if a second is present)
# - **BldgType**: Type of dwelling
# - **HouseStyle**: Style of dwelling
# - **OverallQual**: Overall material and finish quality
# - **OverallCond**: Overall condition rating
# - **YearBuilt**: Original construction date
# - **YearRemodAdd**: Remodel date
# - **RoofStyle**: Type of roof
# - **RoofMatl**: Roof material
# - **Exterior1st**: Exterior covering on house
# - **Exterior2nd**: Exterior covering on house (if more than one material)
# - **MasVnrType**: Masonry veneer type
# - **MasVnrArea**: Masonry veneer area in square feet
# - **ExterQual**: Exterior material quality
# - **ExterCond**: Present condition of the material on the exterior
# - **Foundation**: Type of foundation
# - **BsmtQual**: Height of the basement
# - **BsmtCond**: General condition of the basement
# - **BsmtExposure**: Walkout or garden level basement walls
# - **BsmtFinType1**: Quality of basement finished area
# - **BsmtFinSF1**: Type 1 finished square feet
# - **BsmtFinType2**: Quality of second finished area (if present)
# - **BsmtFinSF2**: Type 2 finished square feet
# - **BsmtUnfSF**: Unfinished square feet of basement area
# - **TotalBsmtSF**: Total square feet of basement area
# - **Heating**: Type of heating
# - **HeatingQC**: Heating quality and condition
# - **CentralAir**: Central air conditioning
# - **Electrical**: Electrical system
# - **1stFlrSF**: First Floor square feet
# - **2ndFlrSF**: Second floor square feet
# - **LowQualFinSF**: Low quality finished square feet (all floors)
# - **GrLivArea**: Above grade (ground) living area square feet
# - **BsmtFullBath**: Basement full bathrooms
# - **BsmtHalfBath**: Basement half bathrooms
# - **FullBath**: Full bathrooms above grade
# - **HalfBath**: Half baths above grade
# - **Bedroom**: Number of bedrooms above basement level
# - **Kitchen**: Number of kitchens
# - **KitchenQual**: Kitchen quality
# - **TotRmsAbvGrd**: Total rooms above grade (does not include bathrooms)
# - **Functional**: Home functionality rating
# - **Fireplaces**: Number of fireplaces
# - **FireplaceQu**: Fireplace quality
# - **GarageType**: Garage location
# - **GarageYrBlt**: Year garage was built
# - **GarageFinish**: Interior finish of the garage
# - **GarageCars**: Size of garage in car capacity
# - **GarageArea**: Size of garage in square feet
# - **GarageQual**: Garage quality
# - **GarageCond**: Garage condition
# - **PavedDrive**: Paved driveway
# - **WoodDeckSF**: Wood deck area in square feet
# - **OpenPorchSF**: Open porch area in square feet
# - **EnclosedPorch**: Enclosed porch area in square feet
# - **3SsnPorch**: Three season porch area in square feet
# - **ScreenPorch**: Screen porch area in square feet
# - **PoolArea**: Pool area in square feet
# - **PoolQC**: Pool quality
# - **Fence**: Fence quality
# - **MiscFeature**: Miscellaneous feature not covered in other categories
# - **MiscVal**: $Value of miscellaneous feature
# - **MoSold**: Month Sold
# - **YrSold**: Year Sold
# - **SaleType**: Type of sale
# - **SaleCondition**: Condition of sale

# %% [markdown]
# **Keeping in mind that there are so many variables here, I need to focus on identifying the main variables or features which makes the real different in predicting the house prices.**

# %% [markdown]
# ## Project Planning Steps<a id='1.4_Project_Plan'></a>

# %% [markdown]
# ![ImageCAR.jpg](attachment:ImageCAR.jpg)

# %% [markdown]
# **The below image demonstrates that I need to focus on keeping the coding, user interface and speed while developing the application:**

# %% [markdown]
# ![ImageMVP.jpg](attachment:ImageMVP.jpg)

# %% [markdown]
# ## Execution Plan<a id='1.5_Execution_Plan'></a>

# %% [markdown]
# As I have the goals and objectives defined, I need to focus on solving this problem.
#
# The main purpose of this execution plan is to put together a map defining the steps and activities to achieve the goals and follow the path for better success.
#
# - **Step-1:** Put together an **Architecture Diagram**
# - **Step-2:** Define the **Machine Learning modeling** activities
# - **Step-3:** Define the **Application Deployment** activities
# - **Step-4:** Put together the **project documentation** to capture the successes and lessons-learned

# %% [markdown]
# ![infographml1.jpg](attachment:infographml1.jpg)

# %% [markdown]
# ### Architecture Diagram<a id='1.4.1_Architecture_Diagram'></a>

# %% [markdown]
# I have created a single diagram explaining what systems, platforms  and tools I am planning to use for this project:
#
# ![ArchitectureDiagram.jpg](attachment:ArchitectureDiagram.jpg)

# %% [markdown]
# ### Machine Learning Pipeline<a id='1.4.2_Machine_Learning_Pipeline'></a>

# %% [markdown]
# I will use the **Data Science Methodology (DSM)** as the pipeline for this project as shown below:
#
# ![MLmethodology.jpg](attachment:MLmethodology.jpg)

# %% [markdown]
# ### Machine Learning App Deployment<a id='1.4.3_Application_Deployment'></a>

# %% [markdown]
# I have created a step by step diagram for this purpose and it is shown below:
#
# ![DeploymentSteps.jpg](attachment:DeploymentSteps.jpg)

# %% [markdown]
# ### Project Documentation<a id='1.4.4_Project_Documentation'></a>

# %% [markdown]
# Project documentation will be captured via Jupyter Notebooks and it will be uploaded on the GitHub. To capture each step, following documents will be prepared:
#
# - **ML Pipeline Notebooks** - There will be dedicated notebooks for each step of the DSM Methodology such as problem definition, data wrangling, EDA, Pre-Processing, and Modeling.
# - **Final ML Steps Notebook** - Final machine learning model along with other steps will be captured on a stand-alone Jupyter Notebook for the next step.
# - **Conversion of Jupyter Notebooks to Scripts** - In order to faciliate the conversion of Jupyter Notebooks into the .py Scripts, I will use the PyCharm to develop these scripts and a snapshot of these scripts will be captured via a separate Notebook.
# - **Development of Flask Scripts** - Using PyCharm, I will create Flask scripts and it will be captured as a snapshot to show it on the stand-alone Juypter Notebook for the record purpose only.
# - **Development of Heroku Scripts** - Similar to Flask Scripts, Heroku scripts will be captured on a stand-alone Jupyter Notebook for the record purpose only.
# - **Final Documentation Notebook** - As part of the DSM Methodology, I follow the last step of creating a final Documentation Jupyter Notebook to put together a final document showing the full journey without the codes. This also includes the creation of power point presentation.

# %% [markdown]
# ## Summary<a id='1.X_Summary'></a>

# %% [markdown]
# Here is the summary of various activities performed under this phase:
#
# - **Defined the problem** and made the presentation to stakeholders to ensure that there is a good alignment on the problem definition
# - **Focused on the problem solving** by brainstorming few solutions and presented those solutions to stakeholders
# - **Developed the written Execution Plan**
# - **Developed solutions for various components of the Execution plan** as per following:
#     - Completed Architecture Plan
#     - Completed Machine Learning Deployment Plan
#     - Developed the plan to capture all the steps of this project as part of the project documentation
#
# - **Reviewed various platform for the deployment** - Reviewed Flask, Streamlit share, Django etc and finalized the plan to use Streamlit apps to GitHub and then to Heroku for the app deployment
#
# The purpose of this notebook is to capture the main problem to be solved and put the planning in place to facilitate the launch of the house prediction application for the demonstration purpose only.

# %% [markdown]
# ## Overview of Execution Steps for the Next Phase<a id='1.6_Execution_Steps'></a>

# %% [markdown]
# ![infographml2-2.jpg](attachment:infographml2-2.jpg)

# %% [markdown]
# ## Quick Access to various Jupyter Notebooks<a id='1.8_Jupyter_Notebooks'></a>

# %% [markdown]
# Based on the DSM methodology, a dedicated jupyter notebook was created to focus on one aspect at a time and you can refer these notebooks from the below links:
#
#    1. For **Problem Identification Notebook** - [click here](https://github.com/jayguptacal/RetailAndMarketing/blob/main/HouseSalesPricePrediction/1_Problem_Identification_House_Prices.ipynb)
#    2. For **Data Wrangling Notebook**, [click here](https://github.com/jayguptacal/RetailAndMarketing/blob/main/HouseSalesPricePrediction/2_Data_Wrangling_House_Prices.ipynb)
#    3. For **Exploratory Data Analysis Notebook**, [click here](https://github.com/jayguptacal/RetailAndMarketing/blob/main/HouseSalesPricePrediction/3_EDA_House_Prices.ipynb)
#    4. For **Pre-Processing and Training Data Development Notebook**, [click here](https://github.com/jayguptacal/RetailAndMarketing/blob/main/HouseSalesPricePrediction/4_Preprocessing_TrainingData_HousePrices.ipynb)
#    5. For **Machine Learning Notebook**, [click here](https://github.com/jayguptacal/RetailAndMarketing/blob/main/HouseSalesPricePrediction/5_Machine_Learning_House_Prices.ipynb)
#    6. For **Full ML Model for Production Purpose**, [click here](https://github.com/jayguptacal/RetailAndMarketing/blob/main/HouseSalesPricePrediction/6a_FullMLPipeline_ProductionPurpose.ipynb)
