# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Data-Wrangling" data-toc-modified-id="Data-Wrangling-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Data Wrangling<a id="2.0_Data_Wrangling"></a></a></span><ul class="toc-item"><li><span><a href="#Importing-Packages-and-Libraries" data-toc-modified-id="Importing-Packages-and-Libraries-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Importing Packages and Libraries<a id="2.1_Imports"></a></a></span></li><li><span><a href="#Loading-the-Dataset" data-toc-modified-id="Loading-the-Dataset-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Loading the Dataset<a id="2.2_Loading_Data"></a></a></span></li><li><span><a href="#Identification-of-Numerical-Variables" data-toc-modified-id="Identification-of-Numerical-Variables-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Identification of Numerical Variables<a id="2.3_Identification_Numerical_Variables"></a></a></span><ul class="toc-item"><li><span><a href="#Identification-of-Temporal-Variables" data-toc-modified-id="Identification-of-Temporal-Variables-2.3.1"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span>Identification of Temporal Variables<a id="2.3.1_Identification_Temporal_Variables"></a></a></span></li><li><span><a href="#Identification-of-Discreet-Variables" data-toc-modified-id="Identification-of-Discreet-Variables-2.3.2"><span class="toc-item-num">2.3.2&nbsp;&nbsp;</span>Identification of Discreet Variables<a id="2.3.2_Identification_Discreet_Variables"></a></a></span></li><li><span><a href="#Identification-of-Continuous-Variables" data-toc-modified-id="Identification-of-Continuous-Variables-2.3.3"><span class="toc-item-num">2.3.3&nbsp;&nbsp;</span>Identification of Continuous Variables<a id="2.3.3_Identification_Continuous_Variables"></a></a></span></li><li><span><a href="#Identification-of-Outliers" data-toc-modified-id="Identification-of-Outliers-2.3.4"><span class="toc-item-num">2.3.4&nbsp;&nbsp;</span>Identification of Outliers<a id="2.3.4_Identification_Outliers"></a></a></span></li></ul></li><li><span><a href="#Identification-of-Categorical-Variables" data-toc-modified-id="Identification-of-Categorical-Variables-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Identification of Categorical Variables<a id="2.4_Identification_Categorical_Variables"></a></a></span><ul class="toc-item"><li><span><a href="#Identification-of-Number-of-Labels-(Cardinality)" data-toc-modified-id="Identification-of-Number-of-Labels-(Cardinality)-2.4.1"><span class="toc-item-num">2.4.1&nbsp;&nbsp;</span>Identification of Number of Labels (Cardinality)<a id="2.4.1_Number_Labels"></a></a></span></li><li><span><a href="#Identification-of-Rare-Labels" data-toc-modified-id="Identification-of-Rare-Labels-2.4.2"><span class="toc-item-num">2.4.2&nbsp;&nbsp;</span>Identification of Rare Labels<a id="2.4.2_Identification_Rare_Labels"></a></a></span></li></ul></li><li><span><a href="#Missing-Values-Analysis" data-toc-modified-id="Missing-Values-Analysis-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Missing Values Analysis<a id="2.5_Missing_Values_Analysis"></a></a></span><ul class="toc-item"><li><span><a href="#Missing-Data-Imputation-Strategy" data-toc-modified-id="Missing-Data-Imputation-Strategy-2.5.1"><span class="toc-item-num">2.5.1&nbsp;&nbsp;</span>Missing Data Imputation Strategy<a id="2.5.1_MissingData_Imputation_Strategy"></a></a></span></li><li><span><a href="#Automatic-Selection-of-Best-Imputation-Technique" data-toc-modified-id="Automatic-Selection-of-Best-Imputation-Technique-2.5.2"><span class="toc-item-num">2.5.2&nbsp;&nbsp;</span>Automatic Selection of Best Imputation Technique<a id="2.5.2_AutomaticSelection_BestImputation_Technique"></a></a></span></li><li><span><a href="#Finding-Relationship-between-Missing-Values-and-House-Prices" data-toc-modified-id="Finding-Relationship-between-Missing-Values-and-House-Prices-2.5.3"><span class="toc-item-num">2.5.3&nbsp;&nbsp;</span>Finding Relationship between Missing Values and House Prices<a id="2.5.3_Finding_Missing_Values_Relationship"></a></a></span></li></ul></li><li><span><a href="#Summary-of-Data-Wrangling-Steps" data-toc-modified-id="Summary-of-Data-Wrangling-Steps-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Summary of Data Wrangling Steps<a id="2.6_Summary_Data_Wrangling"></a></a></span></li><li><span><a href="#Overview-of-Execution-Steps-for-the-Next-Phase" data-toc-modified-id="Overview-of-Execution-Steps-for-the-Next-Phase-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>Overview of Execution Steps for the Next Phase<a id="2.7_Execution_Steps"></a></a></span></li><li><span><a href="#Quick-Access-to-various-Jupyter-Notebooks" data-toc-modified-id="Quick-Access-to-various-Jupyter-Notebooks-2.8"><span class="toc-item-num">2.8&nbsp;&nbsp;</span>Quick Access to various Jupyter Notebooks<a id="2.8_Jupyter_Notebooks"></a></a></span></li></ul></li></ul></div>

# %% [markdown]
# # Data Wrangling<a id='2.0_Data_Wrangling'></a>

# %% [markdown]
# ![MLinfograph2.jpg](attachment:MLinfograph2.jpg)
#
# The focus of this Jupyter notebook is on the data wrangling steps which are as follows:
#
# - Identification of **numerical variables** with the following analysis:
#     - Identification of **temporal variables**
#     - Identification of **discreet variables**
#     - Identification of **continuous variables**
#     - Identification of **outliers**
#
# - Identification of categorical variables with the following analysis:
#
#     - Identification of number of labels (**cardinality**)
#     - Identification of **rare labels**
#
# - Identification of **missing values** and the imputation step will be done in the next phase.
#
# In summary, the focus of this step is on exploring and analyzing the data to decide on the steps required for the feature engineering in the next notebook.

# %% [markdown]
# ## Importing Packages and Libraries<a id='2.1_Imports'></a>

# %%
# Importing the required packages and libraries for the data wrangling purpose only
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# import classes for automatic imputation techniques
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer

# import classes for modeling
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.linear_model import Lasso
from sklearn.model_selection import train_test_split, GridSearchCV

np.random.seed(0)

# Dataframe display settings
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Loading the Dataset<a id='2.2_Loading_Data'></a>

# %%
# Loading the csv data file here from the data folder
data = pd.read_csv('../HousePricesPrediction/data/houseprice.csv')

# %%
# Printing data shape and the dataset
print("Data shape is {} rows and {} columns.".format(data.shape[0], data.shape[1]))
data.head()
# Out:
# Data shape is 1460 rows and 81 columns.
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
# Finding types for various column features
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %% [markdown]
# ## Identification of Numerical Variables<a id='2.3_Identification_Numerical_Variables'></a>

# %%
# First step is to identify the list of numerical variables and print the list

numerical_vars = [var for var in data.columns if data[var].dtypes != 'O']
print("Total number of Numerical Variables are: ", len(numerical_vars))

# Printing the dataset with the numerical variables only
data[numerical_vars].head()
# Out:
# Total number of Numerical Variables are:  38
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          2003       196.0         706           0        150          856
# 1          1976         0.0         978           0        284         1262
# 2          2002       162.0         486           0        434          920
# 3          1970         0.0         216           0        540          756
# 4          2000       350.0         655           0        490         1145
#
# ...

# %% [markdown]
# ### Identification of Temporal Variables<a id='2.3.1_Identification_Temporal_Variables'></a>

# %% [markdown]
# From the visual check-up, it is evident that there are following values which are of temporal type:
#
# - **YearBuilt** - Year when the house was built
# - **YearRemodAdd** - Year when the remodeling was done
# - **GarageYrBlt** - Year when the garage was built
# - **YrSold** - Year when the house was last sold
#
# Based on the above information, I am going to create a list of temporal variables so that the 'year' information can be used to derive more insights.

# %%
# Creating a list of temporal variables
temporal_vars = [var for var in numerical_vars if 'Year' in var or 'Yr' in var]

# Printing the unique values of the year for the temporal_vars from the data
for var in temporal_vars:
    print(var, data[var].unique())
    print()
# Out:
# YearBuilt [2003 1976 2001 1915 2000 1993 2004 1973 1931 1939 1965 2005 1962 2006
#  1960 1929 1970 1967 1958 1930 2002 1968 2007 1951 1957 1927 1920 1966
#  1959 1994 1954 1953 1955 1983 1975 1997 1934 1963 1981 1964 1999 1972
#  1921 1945 1982 1998 1956 1948 1910 1995 1991 2009 1950 1961 1977 1985
#  1979 1885 1919 1990 1969 1935 1988 1971 1952 1936 1923 1924 1984 1926
#  1940 1941 1987 1986 2008 1908 1892 1916 1932 1918 1912 1947 1925 1900
#  1980 1989 1992 1949 1880 1928 1978 1922 1996 2010 1946 1913 1937 1942
#  1938 1974 1893 1914 1906 1890 1898 1904 1882 1875 1911 1917 1872 1905]
#
# YearRemodAdd [2003 1976 2002 1970 2000 1995 2005 1973 1950 1965 2006 1962 2007 1960
#  2001 1967 2004 2008 1997 1959 1990 1955 1983 1980 1966 1963 1987 1964
#  1972 1996 1998 1989 1953 1956 1968 1981 1992 2009 1982 1961 1993 1999
#  1985 1979 1977 1969 1958 1991 1971 1952 1975 2010 1984 1986 1994 1988
#  1954 1957 1951 1978 1974]
#
# ...

# %% [markdown]
# ### Identification of Discreet Variables<a id='2.3.2_Identification_Discreet_Variables'></a>

# %%
# Finding variables which are whole numbers and part of numerical variables but not part of temporal variables
discreet_vars = [var for var in numerical_vars if len(data[var].unique()) < 20 and var not in temporal_vars+['Id']]

# Printing number of discreet variables
print("Total number of discreet variables: ", len(discreet_vars))

# Dataset for the discreet variables
data[discreet_vars].head()
# Out:
# Total number of discreet variables:  14
#    MSSubClass  OverallQual  OverallCond  BsmtFullBath  BsmtHalfBath  FullBath  \
# 0          60            7            5             1             0         2
# 1          20            6            8             0             1         2
# 2          60            7            5             1             0         2
# 3          70            7            5             1             0         1
# 4          60            8            5             1             0         2
#
#    HalfBath  BedroomAbvGr  KitchenAbvGr  TotRmsAbvGrd  Fireplaces  GarageCars  \
# 0         1             3             1             8           0           2
# 1         0             3             1             6           1           2
# 2         1             3             1             6           1           2
# 3         0             3             1             7           1           3
# ...

# %% [markdown]
# ### Identification of Continuous Variables<a id='2.3.3_Identification_Continuous_Variables'></a>

# %%
# Identifying continous variables and creating a list of these variables
continuous_vars = [var for var in numerical_vars if var not in discreet_vars+temporal_vars+['Id']]
print("Total number of continuous variables are: ", len(continuous_vars))
data[continuous_vars].head()
# Out:
# Total number of continuous variables are:  19
#    LotFrontage  LotArea  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  \
# 0         65.0     8450       196.0         706           0        150
# 1         80.0     9600         0.0         978           0        284
# 2         68.0    11250       162.0         486           0        434
# 3         60.0     9550         0.0         216           0        540
# 4         84.0    14260       350.0         655           0        490
#
#    TotalBsmtSF  1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  GarageArea  \
# 0          856       856       854             0       1710         548
# 1         1262      1262         0             0       1262         460
# 2          920       920       866             0       1786         608
# 3          756       961       756             0       1717         642
# 4         1145      1145      1053             0       2198         836
#
# ...

# %% [markdown]
# ### Identification of Outliers<a id='2.3.4_Identification_Outliers'></a>

# %%
# Creating a function to visualize outliers for the continuous variables via box-plots
def find_outliers(df, var):
    df = df.copy()
    # calculating log values for the continous variables
    # since the log value for the negative or zero number can't be calculated, skip those values
    if any(df[var] <=0):
        pass
    else:
        df[var] = np.log(df[var])
        df.boxplot(column=var)
        plt.ylabel(var)
        plt.show()
        
for var in continuous_vars:
    find_outliers(data, var)

# %% [markdown]
# List of outliers under continuous variables is as follows:
#
# - **Lotfrontage**
# - **LotArea**
# - **1stFlrSF**
# - **GrLivArea**
#
# These outliers will impact the performance of the machine learning algorithm, hence I will work on these outliers during the EDA phase.

# %% [markdown]
# ## Identification of Categorical Variables<a id='2.4_Identification_Categorical_Variables'></a>

# %%
# Identifying categorical variables
category_vars = [var for var in data.columns if data[var].dtypes == 'O']
# Printing number of categorical variables in the dataset
print("Total number of categorical variables are ", len(category_vars))
# dataset for the categorical variables
data[category_vars].head()
# Out:
# Total number of categorical variables are  43
#   MSZoning Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 0       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1       RL   Pave   NaN      Reg         Lvl    AllPub       FR2       Gtl
# 2       RL   Pave   NaN      IR1         Lvl    AllPub    Inside       Gtl
# 3       RL   Pave   NaN      IR1         Lvl    AllPub    Corner       Gtl
# 4       RL   Pave   NaN      IR1         Lvl    AllPub       FR2       Gtl
#
#   Neighborhood Condition1 Condition2 BldgType HouseStyle RoofStyle RoofMatl  \
# 0      CollgCr       Norm       Norm     1Fam     2Story     Gable  CompShg
# 1      Veenker      Feedr       Norm     1Fam     1Story     Gable  CompShg
# 2      CollgCr       Norm       Norm     1Fam     2Story     Gable  CompShg
# 3      Crawfor       Norm       Norm     1Fam     2Story     Gable  CompShg
# 4      NoRidge       Norm       Norm     1Fam     2Story     Gable  CompShg
#
# ...

# %% [markdown]
# ### Identification of Number of Labels (Cardinality)<a id='2.4.1_Number_Labels'></a>

# %%
# Listing down number of unique labels for categorical variables
data[category_vars].nunique()
# Out:
# MSZoning          5
# Street            2
# Alley             2
# LotShape          4
# LandContour       4
# Utilities         2
# LotConfig         5
# LandSlope         3
# Neighborhood     25
# Condition1        9
# Condition2        8
# BldgType          5
# HouseStyle        8
# RoofStyle         6
# RoofMatl          8
# Exterior1st      15
# Exterior2nd      16
# MasVnrType        4
# ExterQual         4
# ExterCond         5
# Foundation        6
# BsmtQual          4
# BsmtCond          4
# BsmtExposure      4
# BsmtFinType1      6
# BsmtFinType2      6
# Heating           6
# HeatingQC         5
# CentralAir        2
# Electrical        5
# KitchenQual       4
# Functional        7
# FireplaceQu       5
# GarageType        6
# GarageFinish      3
# GarageQual        5
# GarageCond        5
# PavedDrive        3
# PoolQC            3
# Fence             4
# MiscFeature       4
# SaleType          9
# SaleCondition     6
# dtype: int64

# %% [markdown]
# Number of labels are within the reasonable limit therefore no further action is required.

# %% [markdown]
# ### Identification of Rare Labels<a id='2.4.2_Identification_Rare_Labels'></a>

# %%
# Rare labels are those labels which are present only in a small number of houses.
# Defining a function to identify the rare labels in the categorical variables
def identify_rare_labels(df, var, rare_label_percent):
    df = df.copy()
    # Find out the percentage of observations for each category
    tmp = df.groupby(var).count()['SalePrice'] / len(df)
    # return cateogry that are rare
    return tmp[tmp<rare_label_percent]

# Categories which are less than 1% will be defined as rare labels
for var in category_vars:
    print(identify_rare_labels(data, var, 0.01))
    print()
# Out:
# MSZoning
# C (all)    0.006849
# Name: SalePrice, dtype: float64
#
# Street
# Grvl    0.00411
# Name: SalePrice, dtype: float64
#
# Series([], Name: SalePrice, dtype: float64)
#
# LotShape
# IR3    0.006849
# Name: SalePrice, dtype: float64
#
# Series([], Name: SalePrice, dtype: float64)
#
# Utilities
# NoSeWa    0.000685
# Name: SalePrice, dtype: float64
#
# LotConfig
# FR3    0.00274
# Name: SalePrice, dtype: float64
#
# LandSlope
# Sev    0.008904
# Name: SalePrice, dtype: float64
#
# Neighborhood
# Blueste    0.001370
# NPkVill    0.006164
# Veenker    0.007534
# Name: SalePrice, dtype: float64
#
# Condition1
# PosA    0.005479
# RRAe    0.007534
# RRNe    0.001370
# RRNn    0.003425
# Name: SalePrice, dtype: float64
#
# Condition2
# Artery    0.001370
# Feedr     0.004110
# PosA      0.000685
# PosN      0.001370
# RRAe      0.000685
# RRAn      0.000685
# RRNn      0.001370
# Name: SalePrice, dtype: float64
#
# Series([], Name: SalePrice, dtype: float64)
#
# HouseStyle
# ...

# %% [markdown]
# Labels that are under-represented in the dataset tend to cause over-fitting of machine learning models. Hence these will be removed during the next phase of Jupyter Notebook for Exploratory Data Analysis.

# %% [markdown]
# ## Missing Values Analysis<a id='2.5_Missing_Values_Analysis'></a>

# %%
# Using list comprehension for building a list of variables with the missing values
vars_with_missingvalues = [var for var in data.columns if data[var].isna().sum() > 0]

# Finding out the type of missing values
data[vars_with_missingvalues].dtypes
# Out:
# LotFrontage     float64
# Alley            object
# MasVnrType       object
# MasVnrArea      float64
# BsmtQual         object
# BsmtCond         object
# BsmtExposure     object
# BsmtFinType1     object
# BsmtFinType2     object
# Electrical       object
# FireplaceQu      object
# GarageType       object
# GarageYrBlt     float64
# GarageFinish     object
# GarageQual       object
# GarageCond       object
# PoolQC           object
# Fence            object
# MiscFeature      object
# dtype: object

# %% [markdown]
# From the above results, it is clear that there are missing values in both numerical as well as categorical variables.

# %%
# Finding the percentage of missing values for each variable
data_na = data[vars_with_missingvalues].isna().mean()
# Transform the above array into a DataFrame
data_na = pd.DataFrame(data_na.reset_index())
# Defining columns for the missing data variables
data_na.columns = ['variable', 'missing_value_percentage']
# Sort values of the missing variables in the descending order
data_na.sort_values(by='missing_value_percentage', ascending=False, inplace=True)
# Displaying the missing values
data_na
# Out:
#         variable  missing_value_percentage
# 16        PoolQC                  0.995205
# 18   MiscFeature                  0.963014
# 1          Alley                  0.937671
# 17         Fence                  0.807534
# 10   FireplaceQu                  0.472603
# 0    LotFrontage                  0.177397
# 11    GarageType                  0.055479
# 12   GarageYrBlt                  0.055479
# 13  GarageFinish                  0.055479
# 14    GarageQual                  0.055479
# 15    GarageCond                  0.055479
# 6   BsmtExposure                  0.026027
# 8   BsmtFinType2                  0.026027
# 7   BsmtFinType1                  0.025342
# 5       BsmtCond                  0.025342
# 4       BsmtQual                  0.025342
# 3     MasVnrArea                  0.005479
# 2     MasVnrType                  0.005479
# 9     Electrical                  0.000685

# %% [markdown]
# ### Missing Data Imputation Strategy<a id='2.5.1_MissingData_Imputation_Strategy'></a>

# %% [markdown]
# The following top 6 variables have lot of missing data:
#
# - **PoolQC**
# - **MiscFeature**
# - **Alley**
# - **Fence**
# - **FireplaceQu**
# - **LotFrontage**
#
# So we can't use the simple drop or discard method for the missing data for these variables.

# %% [markdown]
# I am going to use **SimpleImputer** data imputation technique from the SKlearn.
# - **Numerical Variable** - Mean or Median imputation
# - **Categorical Variable** - Most frequent category imputation
#
# Arbitrary value imputation is another option for both numerical and categorical variables.
#
# I am going to create a grid search for the imputation methods to decide which imputation method will work best for these variables.

# %%
# Plotting the histogram of Numerical Variables prior any imputation steps
data[numerical_vars].hist(bins=50, density=True, figsize=(12,12))
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Automatic Selection of Best Imputation Technique<a id='2.5.2_AutomaticSelection_BestImputation_Technique'></a>

# %%
# Separating into training and testing set
X_train, X_test, y_train, y_test = train_test_split(data.drop('SalePrice', axis=1), data['SalePrice'], 
    test_size=0.3, random_state=0)
# Printing shape of both X_train and X_test to check
print("X_train shape: ", X_train.shape)
print("X_test shape: ", X_test.shape)
# Out:
# X_train shape:  (1022, 80)
# X_test shape:  (438, 80)

# %%
features_categorical = [var for var in data.columns if data[var].dtypes=='O']
features_numerical = [var for var in data.columns if data[var].dtypes!='O' and var !='SalePrice']

# Creating pre-processing pipeline for numerical variables
numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())])

# Creating pre_processing pipeline for categorical variables
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='constant', fill_value='missing')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))])

preprocessor = ColumnTransformer(
    transformers=[
        ('numerical', numeric_transformer, features_numerical),
        ('categorical', categorical_transformer, features_categorical)])

# %%
# Creating classifier pipeline
clf = Pipeline(steps=[('preprocessor', preprocessor),('regressor', Lasso(max_iter=1000))])

# %%
# Creating a grid to test all the parameters
param_grid = {
    'preprocessor__numerical__imputer__strategy': ['mean', 'median'],
    'preprocessor__categorical__imputer__strategy': ['most_frequent', 'constant'],
    'regressor__alpha': [10, 100, 200],
}

# creating grid search for the cross validation
grid_search = GridSearchCV(clf, param_grid, cv=5, n_jobs=-1, scoring='r2')

# %%
# Train all the possible combinations of the parameters above
grid_search.fit(X_train, y_train)

# Print the best score over the training set
print(("best linear regression from grid search: %.3f"
       % grid_search.score(X_train, y_train)))
# Out:
# best linear regression from grid search: 0.933

# %%
# Printing the best estimator parameters like this
grid_search.best_estimator_
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('numerical',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['Id', 'MSSubClass',
#                                                    'LotFrontage', 'LotArea',
#                                                    'OverallQual', 'OverallCond',
#                                                    'YearBuilt', 'YearRemodAdd',
#                                                    'MasVnrArea', 'BsmtFinSF1',
#                                                    'BsmtFinSF2', 'BsmtUnfSF',
# ...

# %%
# Find the best fit parameters 
grid_search.best_params_
# Out:
# {'preprocessor__categorical__imputer__strategy': 'constant',
#  'preprocessor__numerical__imputer__strategy': 'median',
#  'regressor__alpha': 100}

# %%
# Find the scores for each of one of the above combinations
grid_search.cv_results_['mean_test_score']
# Out:
# array([0.84746254, 0.86624908, 0.86552764, 0.84739594, 0.86621021,
#        0.8654755 , 0.84814964, 0.86646886, 0.86525292, 0.8481309 ,
#        0.86651035, 0.86523714])

# %%
# Check the performance over the test set
print(("best linear regression from grid search: %.3f"
       % grid_search.score(X_test, y_test)))
# Out:
# best linear regression from grid search: 0.738

# %% [markdown]
# For the training set, r-squared value is 0.933 and for the testing set it is 0.738. This means the model is overfitting and it needs to be tuned further.

# %% [markdown]
# ### Finding Relationship between Missing Values and House Prices<a id='2.5.3_Finding_Missing_Values_Relationship'></a>

# %%
# Defining a function to plot the relationship between the variables with the missing values and house prices.

def na_impact_prices(df, var):
    df = df.copy()
    df[var] = np.where(df[var].isna(), 1, 0) # defining '1' for missing values and '0' for no-missing values
    # plotting for the median sale prices vs. the variable with the missing values
    # Considering median and not mean prices because of missing values and outliers
    df.groupby(var)['SalePrice'].median().plot.bar(title=var + ' ' +"Missing Values Impact on Prices") 
    plt.show()
    
# Running the above function on the missing data variables
for var in vars_with_missingvalues:
    na_impact_prices(data, var)

# %% [markdown]
# Based on the missing values, it is obvious that there is some impact on the average sales price but it is hard to establish any definitive pattern.
#
# Since the goal is to find the best model which is simple, easy to implement and easy to maintain during the production phase, another technique will be used to deal with missing values in the EDA phase keeping in mind the knowledge gained during this exercise.

# %% [markdown]
# ## Summary of Data Wrangling Steps<a id='2.6_Summary_Data_Wrangling'></a>

# %% [markdown]
# Here is the summary of various findings of the data wrangling steps:
#
# - **Number of rows & columns** - 1460 rows and 81 columns
# - **Numerical variables** - There are a total of 38 numerical variables.
# - **Temporal variables** - There are 4 temporal variables (YearBuilt, YearRemodAdd, GarageYrBlt & YrSold)out of above 38 numerical variables.
# - **Discreet variable** - There are a total of 14 discreet variables out of the total 38 numerical variables.
# - **Continous variable** - There are a total of 19 continuous variables out of the total 38 numerical variables.
# - **Outliers** - These variables (Lotfrontage, LotArea, 1stFlrSF & GrLivArea) have been identified with outliers.
# - **Categorical variables** - There are 43 categorical variables.
# - **Cardinality** - Based on the analysis, no further action is required.
# - **Rare labels** - A list of rare labels has been identified which will be resolved during the EDA steps.
# - **Missing Values** - Extensive missing value analysis has been done using Lasso regression model and it will be further analyzed in the EDA steps as my goal is to keep it simple for the production purpose.
# - **Impact of Missing Values** - The impact of the missing values on the house prices was identified for various features and there were some prominent features which impacted the house pricing significantly.

# %% [markdown]
# ## Overview of Execution Steps for the Next Phase<a id='2.7_Execution_Steps'></a>

# %% [markdown]
# ![infographml3-2.jpg](attachment:infographml3-2.jpg)

# %% [markdown]
# ## Quick Access to various Jupyter Notebooks<a id='2.8_Jupyter_Notebooks'></a>

# %% [markdown]
# Based on the DSM methodology, a dedicated jupyter notebook was created to focus on one aspect at a time and you can refer these notebooks from the below links:
#
#    1. For **Problem Identification Notebook** - [click here](https://github.com/jayguptacal/RetailAndMarketing/blob/main/HouseSalesPricePrediction/1_Problem_Identification_House_Prices.ipynb)
#    2. For **Data Wrangling Notebook**, [click here](https://github.com/jayguptacal/RetailAndMarketing/blob/main/HouseSalesPricePrediction/2_Data_Wrangling_House_Prices.ipynb)
#    3. For **Exploratory Data Analysis Notebook**, [click here](https://github.com/jayguptacal/RetailAndMarketing/blob/main/HouseSalesPricePrediction/3_EDA_House_Prices.ipynb)
#    4. For **Pre-Processing and Training Data Development Notebook**, [click here](https://github.com/jayguptacal/RetailAndMarketing/blob/main/HouseSalesPricePrediction/4_Preprocessing_TrainingData_HousePrices.ipynb)
#    5. For **Machine Learning Notebook**, [click here](https://github.com/jayguptacal/RetailAndMarketing/blob/main/HouseSalesPricePrediction/5_Machine_Learning_House_Prices.ipynb)
#    6. For **Full ML Model for Production Purpose**, [click here](https://github.com/jayguptacal/RetailAndMarketing/blob/main/HouseSalesPricePrediction/6a_FullMLPipeline_ProductionPurpose.ipynb)
